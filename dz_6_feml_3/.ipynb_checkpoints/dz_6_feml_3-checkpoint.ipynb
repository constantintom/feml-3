# %% [markdown]
# ### Задание
# ### Вопросы по заданию
# ### Преподаватель: Наталья Баданина
#
# * См. материалы к занятию.
#
# * Для выполнения домашнего задания необходимо взять файл boston house-prices datase (sklearn.datasets.load_boston) и построить модель.
# * По аналогии задания к лекции «Классификация: Логистическая регрессия и SVM».
# * А именно построить модель регрессии, дерево решений, оптимизировать параметры и сравнить результаты.

# %%
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
boston = load_boston()

df = pd.DataFrame(boston.data, columns=boston.feature_names)
df = pd.concat([df, pd.DataFrame(boston.target, columns=['MEDV'])], axis=1)
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# #### Разделим стоимость домов на 3 класса:
# *   ниже среднего < 17.0;
# *     средняя <=25000 >=17.0
# *        выше среднего > 25.0

# %% [markdown]
# #### Создаём новый столбец с целевой переменной

# %%
def get_group(x):    
    if x in df.loc[df.MEDV < df.MEDV.quantile(.25)].values:
        return 'low'
    elif x in df.loc[(df.MEDV >= df.MEDV.quantile(.25)) & (df.MEDV <= df.MEDV.quantile(.75))].values:
        return 'average'
    elif x in df.loc[df.MEDV > df.MEDV.quantile(.75)].values:
        return 'high'
    
df['PRICE'] = df['MEDV'].apply(get_group)
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
#  14  PRICE    506 non-null    object
# dtypes: float64(14), object(1)
# memory usage: 59.4+ KB
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(df.PRICE)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['average', 'high', 'low'], dtype=object)

# %%
df.PRICE = le.transform(df.PRICE)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV  PRICE
# 0       15.3  396.90   4.98  24.0      2
# ...

# %%
y = df.PRICE
X = df.drop(['PRICE', 'MEDV'], axis=1)
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %% [markdown]
# #### 1. Построение модели логистической регрессии

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
st = StandardScaler()
X_train_std = st.fit_transform(X_train)
X_test_std = st.transform(X_test)
y_train.shape
# Out:
# (354,)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty='l1', solver='liblinear', multi_class='ovr', C = 0.1)
model.fit(X_train_std, y_train)
# Out:
# LogisticRegression(C=0.1, multi_class='ovr', penalty='l1', solver='liblinear')

# %%
y_pred = model.predict(X_test_std)
model.predict_proba(X_test_std)[:5]
# Оцениваем верность модели на тестовых данных
model.score(X_test_std, y_test)
# Out:
# 0.6513157894736842

# %% [markdown]
# ##### Оценим влияние параметра С

# %%
fig = plt.figure()
ax = plt.subplot(111)
    
colors = ['blue', 'green', 'red', 'cyan', 
          'magenta', 'yellow', 'black', 
          'pink', 'lightgreen', 'lightblue', 
          'gray', 'indigo', 'orange']

weights, params = [], []
for c in np.arange(-4., 6.):
    lr = LogisticRegression(penalty='l1', C=10.**c, solver='liblinear', 
                            multi_class='ovr', random_state=0)
    lr.fit(X_train_std, y_train)
    weights.append(lr.coef_[1])
    params.append(10**c)

weights = np.array(weights)

for column, color in zip(range(weights.shape[1]), colors):
    plt.plot(params, weights[:, column],
             label=X.columns[column],
             color=color)
plt.axhline(0, color='black', linestyle='--', linewidth=3)
plt.xlim([10**(-5), 10**5])
plt.ylabel('weight coefficient')
plt.xlabel('C')
plt.xscale('log')
plt.legend(loc='upper left')
ax.legend(loc='upper center', 
          bbox_to_anchor=(1.38, 1.03),
          ncol=1, fancybox=True)
plt.show()

# %% [markdown]
# ##### Оценим значимость фичей

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=3)
clf.fit(X, y)

plt.barh(np.arange(len(clf.feature_importances_)), clf.feature_importances_)
plt.yticks(np.arange(len(X.columns)),X.columns)
# Out:
# ([<matplotlib.axis.YTick at 0x15b726798b0>,
# ...
#  [Text(0, 0, 'CRIM'),
#   Text(0, 1, 'ZN'),
#   Text(0, 2, 'INDUS'),
#   Text(0, 3, 'CHAS'),
#   Text(0, 4, 'NOX'),
#   Text(0, 5, 'RM'),
#   Text(0, 6, 'AGE'),
#   Text(0, 7, 'DIS'),
#   Text(0, 8, 'RAD'),
#   Text(0, 9, 'TAX'),
#   Text(0, 10, 'PTRATIO'),
#   Text(0, 11, 'B'),
#   Text(0, 12, 'LSTAT')])

# %% [markdown]
# #### Построение дерева решений

# %%
tree = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
y_pred_tree = tree.predict(X_test)
tree.predict_proba(X_test)[:5]
# Out:
# array([[0.79569892, 0.05376344, 0.15053763],
#        [0.79569892, 0.05376344, 0.15053763],
#        [0.79569892, 0.05376344, 0.15053763],
#        [0.04918033, 0.        , 0.95081967],
#        [0.66216216, 0.02702703, 0.31081081]])

# %%
# Оцениваем верность модели на тестовых данных
tree.score(X_test, y_test)
# Out:
# 0.6842105263157895

# %% [markdown]
# ##### Возьмем наиболее значимые признаки

# %%
X2 = X[['LSTAT', 'RM', 'CRIM']]
X2
# Out:
#      LSTAT     RM     CRIM
# 0     4.98  6.575  0.00632
# 1     9.14  6.421  0.02731
# 2     4.03  7.185  0.02729
# 3     2.94  6.998  0.03237
# 4     5.33  7.147  0.06905
# ..     ...    ...      ...
# 501   9.67  6.593  0.06263
# 502   9.08  6.120  0.04527
# 503   5.64  6.976  0.06076
# 504   6.48  6.794  0.10959
# 505   7.88  6.030  0.04741
#
# [506 rows x 3 columns]

# %% [markdown]
# #### Построим модель Логистической регрессии

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y, test_size=0.3, random_state=0)

# %%
st = StandardScaler()
X2_train_std = st.fit_transform(X2_train)
X2_test_std = st.transform(X2_test)
y2_train.shape
# Out:
# (354,)

# %% [markdown]
# #### Используем оптимальный коэффициент С

# %%
model2 = LogisticRegression(penalty='l1', solver='liblinear', multi_class='ovr', C = 0.2)
model2.fit(X2_train_std, y2_train)
# Out:
# LogisticRegression(C=0.2, multi_class='ovr', penalty='l1', solver='liblinear')

# %%
y2_pred = model2.predict(X2_test_std)
model2.predict_proba(X2_test_std)[:5]
# Out:
# array([[0.62813941, 0.25236322, 0.11949737],
#        [0.36179477, 0.17171513, 0.4664901 ],
#        [0.6078018 , 0.17979307, 0.21240513],
#        [0.07178075, 0.0092917 , 0.91892755],
#        [0.60919846, 0.11551738, 0.27528416]])

# %%
# Оцениваем верность модели на тестовых данных
model2.score(X2_test_std, y2_test)
# Out:
# 0.7236842105263158

# %% [markdown]
# ##### Верность модели линейной регрессии улучшилась

# %% [markdown]
# #### Оптимизация дерева решений

# %%
tree2 = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=100)
tree2.fit(X2_train, y2_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=100)

# %%
y2_pred_tree = tree2.predict(X2_test)
tree2.predict_proba(X2_test)[:5]
# Out:
# array([[0.82022472, 0.06741573, 0.11235955],
#        [0.25      , 0.25      , 0.5       ],
#        [0.82022472, 0.06741573, 0.11235955],
#        [0.04918033, 0.        , 0.95081967],
#        [0.68518519, 0.03703704, 0.27777778]])

# %%
# Оцениваем верность модели на тестовых данных
tree2.score(X2_test, y2_test)
# Out:
# 0.6907894736842105

# %% [markdown]
# ##### Верность дерева решений улучшилась
